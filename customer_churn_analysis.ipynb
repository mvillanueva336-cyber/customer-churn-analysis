# %%
import pandas as pd

data = pd.read_csv("telco_churn.csv")

data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
import matplotlib.pyplot as plt

data["Churn"].value_counts().plot(kind="bar")

plt.title("Customer Churn Distribution")
plt.ylabel("Number of Customers")
plt.xlabel("Churn")
plt.show()

# %%
import pandas as pd

pd.crosstab(data["Contract"], data["Churn"]).plot(kind="bar")

plt.title("Customer Churn by Contract Type")
plt.ylabel("Number of Customers")
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="Churn", y="MonthlyCharges", data=data)

plt.title("Monthly Charges vs Customer Churn")
plt.show()

# %%
sns.boxplot(x="Churn", y="tenure", data=data)

plt.title("Customer Tenure vs Churn")
plt.show()

# %%
churn_rate = data.groupby("PaymentMethod")["Churn"].value_counts(normalize=True).unstack()

churn_rate["Yes"].plot(kind="bar")

plt.title("Churn Rate by Payment Method")
plt.ylabel("Churn Rate")
plt.show()

# %%
data.to_csv("telco_churn_clean.csv", index=False)
